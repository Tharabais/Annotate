# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharabais/Annotate/blob/main/DataScienceLifecycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as pIt
df=pd.read_excel("/content/Student_performance_data.xlsx")
print('student Dataset')
print(df.describe())
df.head()
# Out:
# student Dataset
#             Math   Science     English
# count   5.000000   5.000000   5.000000
# mean   81.600000  87.400000  82.800000
# std     9.370165   4.929503   3.271085
# min    69.000000  84.000000  78.000000
# 25%    75.000000  85.000000  82.000000
# 50%    85.000000  85.000000  83.000000
# 75%    87.000000  87.000000  84.000000
# max    92.000000  96.000000  87.000000
#    Name   Math  Science   English
# 0   Arun    75        85       83
# 1  Meena    92        84       82
# 2  Kiran    85        87       84
# 3   John    69        96       87
# 4  Priya    87        85       78

# %%
from google.colab import drive
drive.mount('/content/drive')
