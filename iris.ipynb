# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharabais/Annotate/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#simple python code for describing data
#import libraries
import pandas as pd
from sklearn.datasets import load_iris
#load sample dataset
iris=load_iris()
#convert into DataFrame
data=pd.DataFrame(iris.data,columns=iris.feature_names)
#Display first 5 rows
print("FIRST 5 ROWS OF DATASET")
print(data.head())
#display dataset shape
print("\nDATASET SHAPE")
print(data.shape)
#display column names
print("\nCOLUMN NAMES")
print(data.columns)
#Statistical description
print("\nSTATISCAL SUMMARY")
print(data.describe())
#Check missing values
print("\nMISSING VALUES")
print(data.isnull().sum())
# Out:
# FIRST 5 ROWS OF DATASET
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# DATASET SHAPE
# (150, 4)
#
# COLUMN NAMES
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')
#
# STATISCAL SUMMARY
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# ...
